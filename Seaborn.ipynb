# %%
# import libraries first
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data first
fifa_data = pd.read_csv(r"C:\Users\David gathara marigi\Downloads\fifa.csv", index_col = 'Date', parse_dates = True)

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(data = fifa_data)
# Out:
# <Axes: xlabel='Date'>

# %%
spotify_data = pd.read_csv(r"C:\Users\David gathara marigi\Downloads\spotify.csv", parse_dates=["track_album_release_date"])
spotify_data.set_index("track_album_release_date", inplace=True)

# %%
spotify_data.head()
# Out:
#                                         track_id  \
# track_album_release_date
# 2019-06-14                6f807x0ima9a1j3VPbc7VN
# 2019-12-13                0r7CVbZTWZgbTCYdfa2P31
# 2019-07-05                1z1Hg7Vb0AhHDiEmnDE79l
# 2019-07-19                75FpbthrwQmzHlBJLuGdC7
# 2019-03-05                1e8PAfcKUYoKkxPhrHqw4x
#
#                                                                  track_name  \
# track_album_release_date
# 2019-06-14                I Don't Care (with Justin Bieber) - Loud Luxur...
# 2019-12-13                                  Memories - Dillon Francis Remix
# 2019-07-05                                  All the Time - Don Diablo Remix
# 2019-07-19                                Call You Mine - Keanu Silva Remix
# 2019-03-05                          Someone You Loved - Future Humans Remix
#
#                               track_artist  track_popularity  \
# track_album_release_date
# 2019-06-14                      Ed Sheeran                66
# ...

# %%
spotify_data.tail()
# Out:
#                                         track_id  \
# track_album_release_date
# 2014-04-28                7bxnKAamR3snQ1VGLuVfC1
# 2013-03-08                5Aevni09Em4575077nkWHz
# 2014-04-21                7ImMqPP3Q1yfUHvsdn7wEo
# 2014-01-01                2m69mhnfQ1Oq6lGtXuYhgX
# 2014-03-03                29zWqhca3zt5NsckZqDf6c
#
#                                                     track_name  \
# track_album_release_date
# 2014-04-28                City Of Lights - Official Radio Edit
# 2013-03-08                 Closer - Sultan & Ned Shepard Remix
# 2014-04-21                        Sweet Surrender - Radio Edit
# 2014-01-01                      Only For You - Maor Levi Remix
# 2014-03-03                              Typhoon - Original Mix
#
#                             track_artist  track_popularity  \
# track_album_release_date
# 2014-04-28                  Lush & Simon                42
# 2013-03-08                Tegan and Sara                20
# ...

# %%
#sns.lineplot tells the code we want to create a line chart
plt.figure(figsize=(14, 6))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
sns.lineplot(data = spotify_data)

# %%
list(spotify_data)
# Out:
# ['track_id',
#  'track_name',
#  'track_artist',
#  'track_popularity',
#  'track_album_id',
#  'track_album_name',
#  'playlist_name',
#  'playlist_id',
#  'playlist_genre',
#  'playlist_subgenre',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms']

# %%
plt.figure(figsize=(14,6))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")
shape_data = spotify_data[spotify_data['track_name'] == 'Shape of You']
despacito_data = spotify_data[spotify_data['track_name'] == 'Despacito']

sns.lineplot(data=shape_data, x=shape_data.index, y='track_popularity', label='Shape of You song')
sns.lineplot(data=despacito_data, x=despacito_data.index, y='track_popularity', label='Despacito song')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
flight_data = pd.read_csv(r"C:\Users\David gathara marigi\Downloads\flight_delays.csv", index_col = 'Month')
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
'''x=flight_data.index - This determines what to use on the horizontal axis. 
In this case, we have selected the column that indexes the rows (in this case, the column containing the months).
y=flight_data['NK'] - This sets the column in the data that will be used to determine the height of each bar. 
In this case, we select the 'NK' column.
Important Note: 
You must select the indexing column with flight_data.index, and it is not possible to use flight_data['Month'] (which will return an error). 
This is because when we loaded the dataset, the "Month" column was used to index the rows. 
We always have to use this special notation to select the indexing column.'''
# Out:
# 'x=flight_data.index - This determines what to use on the horizontal axis. \nIn this case, we have selected the column that indexes the rows (in this case, the column containing the months).\ny=flight_data[\'NK\'] - This sets the column in the data that will be used to determine the height of each bar. \nIn this case, we select the \'NK\' column.\nImportant Note: \nYou must select the indexing column with flight_data.index, and it is not possible to use flight_data[\'Month\'] (which will return an error). \nThis is because when we loaded the dataset, the "Month" column was used to index the rows. \nWe always have to use this special notation to select the indexing column.'

# %%
plt.figure(figsize=(16, 6))
plt.title('Average Arrival Delay for Spirit Airlines Flights, by Month')
sns.barplot(x=flight_data.index, y = flight_data['NK'])
plt.ylabel('Arrival delay (in minutes)')
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %%
plt.figure(figsize=(16, 6))
plt.title("Average Arrival Delay for Each Airline, by Month")
sns.heatmap(data = flight_data, annot = True)
plt.xlabel('Airline')
# Out:
# Text(0.5, 36.72222222222221, 'Airline')

# %%
ign_data = pd.read_csv(r"C:\Users\David gathara marigi\Downloads\ign_scores.csv", index_col="Platform")
ign_data.head()
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# ...

# %%
plt.figure(figsize=(16, 6))
sns.barplot(x=ign_data['Racing'], y=ign_data.index)
# Out:
# <Axes: xlabel='Racing', ylabel='Platform'>

# %%
sns.heatmap(data=ign_data, annot=True)
# Out:
# <Axes: ylabel='Platform'>

# %%
iris_data = pd.read_csv(r"C:\Users\David gathara marigi\Downloads\iris.csv", index_col='Id')

# %%
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
sns.histplot(data=iris_data['Petal Length (cm)'])
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'], fill=True)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde")

# %%
#hue= sets the column we'll use to split the data into different histograms
# Histograms for each species
sns.histplot(data=iris_data, x='Petal Length (cm)', hue='Species')

# Add title
plt.title("Histogram of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lengths, by Species')

# %%
# Histograms for each species
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', fill=True)

# Add title
plt.title("Histogram of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lengths, by Species')
